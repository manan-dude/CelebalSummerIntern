# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/laptop-league-a-comprehensive-dataset-for-laptops/Laptop_Information.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/kaggle/input/laptop-league-a-comprehensive-dataset-for-laptops/Laptop_Information.csv')

# %%
df.sample(5)
# Out:
#      Unnamed: 0  Company  Rating  No_of_ratings  Review  Size  \
# 625         625  Infinix     4.2             54      17  40.0
# 596         596   Lenovo     4.4            194      19  40.0
# 263         263   Lenovo     4.3            252      29  40.0
# 269         269     DELL     4.1            340      32  40.0
# 704         704   Lenovo     5.0              4       0  36.0
#
#                                              Processor  RAM  \
# 625                 Intel Core i5 Processor (12th Gen)   16
# 596                 Intel Core i5 Processor (11th Gen)    8
# 263                 Intel Core i5 Processor (11th Gen)    8
# 269  Processor: Intel PQC-N5030 (1.10 GHz up to 3.1...    8
# 704                 Intel Core i3 Processor (10th Gen)    8
#
#                                  Memory                               OpSys  \
# 625                          512 GB SSD                         Windows 11
# ...

# %%
df.shape
# Out:
# (984, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     984 non-null    int64
#  1   Company        984 non-null    object
#  2   Rating         984 non-null    float64
#  3   No_of_ratings  984 non-null    int64
#  4   Review         984 non-null    int64
#  5   Size           984 non-null    float64
#  6   Processor      984 non-null    object
#  7   RAM            984 non-null    int64
#  8   Memory         984 non-null    object
#  9   OpSys          984 non-null    object
#  10  Price          984 non-null    int64
#  11  MRP            984 non-null    int64
#  12  ImgURL         984 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 100.1+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Company          0
# Rating           0
# No_of_ratings    0
# Review           0
# Size             0
# Processor        0
# RAM              0
# Memory           0
# OpSys            0
# Price            0
# MRP              0
# ImgURL           0
# dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['Price'])
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
plt.figure(figsize=(12,6))
df['Company'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['Size'])
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=df['Size'],y=df["Price"])
plt.show()

# %%
df.corr()['Price']
# Out:
# Unnamed: 0      -0.084586
# Rating           0.141088
# No_of_ratings    0.214972
# Review           0.143633
# Size            -0.027583
# RAM              0.718267
# Price            1.000000
# MRP              0.855394
# Name: Price, dtype: float64

# %%
df['Processor'].value_counts()
# Out:
# Intel Core i5 Processor (11th Gen)                               181
# Intel Core i3 Processor (11th Gen)                               122
# AMD Ryzen 5 Hexa Core Processor                                  102
# Intel Core i5 Processor (12th Gen)                                97
# AMD Ryzen 7 Octa Core Processor                                   76
#                                                                 ...
# NVIDIA GeForce GTX 1660 Ti                                         1
# Processor: Intel i7-11800H- (2.30 GHz up to 4.60 GHz) 16MB L3      1
# Apple M1 Max Processor                                             1
# AMD Ryzen 7 Octa Core Processor (5th Gen)                          1
# Intel Pentium Quad Core Processor (10th Gen)                       1
# Name: Processor, Length: 87, dtype: int64

# %%
df['Processor Name']=df['Processor'].apply(lambda x:' '.join(x.split()[0:3]))

# %%
df.sample()
# Out:
#     Unnamed: 0 Company  Rating  No_of_ratings  Review  Size  \
# 80          80    acer     4.4            431      38  40.0
#
#                              Processor  RAM      Memory               OpSys  \
# 80  Intel Core i3 Processor (11th Gen)    8  256 GB SSD  64 bit Windows 11
#
#     Price    MRP                                             ImgURL  \
# 80  32489  43999  https://rukminim1.flixcart.com/image/312/312/x...
#
#    Processor Name
# 80  Intel Core i3

# %%
def fetch_processor(text):
    if text == 'AMD Ryzen 5' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df.sample(5)
# Out:
#      Unnamed: 0 Company    Rating  No_of_ratings  Review  Size  \
# 749         749   APPLE  4.500000            482      50  34.0
# 860         860    DELL  4.000000             35       2  40.0
# 879         879  Lenovo  4.300000           2841     241  40.0
# 762         762    ASUS  4.253597           2841     241  40.0
# 199         199  Lenovo  4.300000           2841     241  40.0
#
#                                       Processor  RAM               Memory  \
# 749                          Apple M1 Processor    8           512 GB SSD
# 860          Intel Core i5 Processor (11th Gen)    8  1 TB HDD|256 GB SSD
# 879          Intel Core i5 Processor (11th Gen)    8           512 GB SSD
# 762  AMD Ryzen 5 Hexa Core Processor (10th Gen)    8           512 GB SSD
# 199          Intel Core i5 Processor (11th Gen)    8           512 GB SSD
#
#                   OpSys   Price     MRP  \
# 749             Mac OS   128490  142900
# 860  64 bit Windows 11    65990   85900
# ...

# %%
df['Processor brand'] = df['Processor Name'].apply(fetch_processor)

# %%
plt.figure(figsize=(12,6))
df['Processor brand'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['Processor brand'],y=df['Price'])
plt.show()

# %%
df.drop(columns=['Processor','Processor Name'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company  Rating  No_of_ratings  Review  Size  RAM  \
# 0           0      HP     4.2            253      20  36.0   16
# 1           1  Lenovo     4.2            974      75  36.0    8
# 2           2    ASUS     4.4           5389     535  40.0    8
# 3           3    DELL     4.1            332      26  40.0    8
# 4           4    ASUS     4.2            487      53  40.0    8
#
#                                     Memory  \
# 0                               512 GB SSD
# 1                               256 GB SSD
# 2                               512 GB SSD
# 3  Display: 15.6" FHD WVA AG Narrow Border
# 4                               512 GB SSD
#
#                                                OpSys  Price    MRP  \
# 0                                 64 bit Windows 11   49990  59240
# 1                                 64 bit Windows 11   33990  60890
# 2                                        Windows 11   49990  70990
# ...

# %%
plt.figure(figsize=(12,6))
df['RAM'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=df['RAM'],y=df['Price'])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr())
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.distplot(np.log(df['Price']))
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
